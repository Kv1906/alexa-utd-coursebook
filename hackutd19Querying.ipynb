# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("mockCourseData.csv")

# %%
df.head()
# Out:
#    Id    Term  TermYear Status  Section ClassLevel ClassSubLevel ClassNumber  \
# 0   1  Summer      2019      O  CS 2375         UG            SO         123
# 1   2  Spring      2019      C  CS 3375         UG             J         124
# 2   3    Fall      2019      O  CS 1375         UG             F         125
# 3   4  Spring      2019      O  CS 4375         UG             S         126
# 4   5  Spring      2019      O  CS 5575          G            GP         12q
#
#          ClassTitle  CourseCredits     Instructor              Days  \
# 0  Machine learning              3  Dan Molodovan  Monday&Wednesday
# 1          Big data              3   Anurag Nagar  Tuesday&Thursday
# 2  Machine learning              3    Anjum Chida  Tuesday&Thursday
# 3             Stats              3   Anurag Nagar  Monday&Wednesday
# 4                DB              2          Davis  Monday&Wednesday
#
#    StartTime  EndTime    Location InstructionMode
# 0        9.0    10.15  ECSS 2.410               o
# 1        9.0    10.15  ECSS 2.412               o
# 2       10.3    11.45  ECSS 2.415               o
# 3       10.3    11.45  ECSS 2.410               r
# 4       14.3    15.45  ECSS 2.410               r

# %%
def isStringAvailable(string):
  return string!=None and len(string)!=0

# %%
#CourseOfferedSemesterIntent
termAndYear = "Summer 2019"
result = None
if(termAndYear!=None or len(termAndYear)!=0):
  term = termAndYear.split(" ")[0]
  termYear = termAndYear.split(" ")[1]
  result = df[(df['Term'] == term) & (df['TermYear'] == int(termYear))]
result
# Out:
#    Id    Term  TermYear Status  Section ClassLevel ClassSubLevel ClassNumber  \
# 0   1  Summer      2019      O  CS 2375         UG            SO         123
# 7   8  Summer      2019      C  CS 6375          G            GP         128
# 8   9  Summer      2019      O  CS 7375          P             P         129
# 9  10  Summer      2019      O  CS 1325         UG             F         120
#
#          ClassTitle  CourseCredits     Instructor              Days  \
# 0  Machine learning              3  Dan Molodovan  Monday&Wednesday
# 7               CNN              3         arthur            Friday
# 8                AI              3           Haim          Saturday
# 9               NLP              3            Dan          Saturday
#
#    StartTime  EndTime    Location InstructionMode
# 0        9.0    10.15  ECSS 2.410               o
# 7       16.0    18.45  ECSS 2.412               r
# 8       16.0    18.45  ECSS 2.410               r
# 9       14.0    16.45  ECSS 2.415               r

# %%
#CourseBookDayIntent
result = None
day = "weekday"
weekday = ["monday","tuesday","wednesday","thursday","friday"]
weekend = ["saturday","sunday"]
if(day.lower() == 'weekday'):
  result = df[df['Days'].str.lower().str.contains("monday") | df['Days'].str.lower().str.contains("tuesday") | df['Days'].str.lower().str.contains("wednesday")
            | df['Days'].str.lower().str.contains("thursday") | df['Days'].str.lower().str.contains("friday")]
elif(day.lower() == 'weekend'):
  result = df[df['Days'].str.lower().str.contains("saturday") | df['Days'].str.lower().str.contains("sunday")]
else:
  result = df[df['Days'].str.lower().str.contains(day.lower())]
result
# Out:
#    Id    Term  TermYear Status  Section ClassLevel ClassSubLevel ClassNumber  \
# 0   1  Summer      2019      O  CS 2375         UG            SO         123
# 1   2  Spring      2019      C  CS 3375         UG             J         124
# 2   3    Fall      2019      O  CS 1375         UG             F         125
# 3   4  Spring      2019      O  CS 4375         UG             S         126
# 4   5  Spring      2019      O  CS 5575          G            GP         12q
# 5   6  Spring      2019      O  CS 6575          G            GR         122
# 6   7    Fall      2019      C  CS 5375          G            GR         127
# 7   8  Summer      2019      C  CS 6375          G            GP         128
#
#                           ClassTitle  CourseCredits     Instructor  \
# 0                   Machine learning              3  Dan Molodovan
# 1                           Big data              3   Anurag Nagar
# 2                   Machine learning              3    Anjum Chida
# 3                              Stats              3   Anurag Nagar
# 4                                 DB              2          Davis
# 5                                SDN              1        Timothy
# 6  Design and Analysis of algorithms              3         Balaji
# 7                                CNN              3         arthur
#
#                Days  StartTime  EndTime    Location InstructionMode
# 0  Monday&Wednesday        9.0    10.15  ECSS 2.410               o
# 1  Tuesday&Thursday        9.0    10.15  ECSS 2.412               o
# 2  Tuesday&Thursday       10.3    11.45  ECSS 2.415               o
# 3  Monday&Wednesday       10.3    11.45  ECSS 2.410               r
# 4  Monday&Wednesday       14.3    15.45  ECSS 2.410               r
# 5  Monday&Wednesday       20.3    21.45  ECSS 2.410               r
# 6  Monday&Wednesday       16.3    17.45  ECSS 2.415               r
# 7            Friday       16.0    18.45  ECSS 2.412               r

# %%
#CourseCreditIntent
credits = 3
df[df["CourseCredits"]==credits]
# Out:
#    Id    Term  TermYear Status  Section ClassLevel ClassSubLevel ClassNumber  \
# 0   1  Summer      2019      O  CS 2375         UG            SO         123
# 1   2  Spring      2019      C  CS 3375         UG             J         124
# 2   3    Fall      2019      O  CS 1375         UG             F         125
# 3   4  Spring      2019      O  CS 4375         UG             S         126
# 6   7    Fall      2019      C  CS 5375          G            GR         127
# 7   8  Summer      2019      C  CS 6375          G            GP         128
# 8   9  Summer      2019      O  CS 7375          P             P         129
# 9  10  Summer      2019      O  CS 1325         UG             F         120
#
#                           ClassTitle  CourseCredits     Instructor  \
# 0                   Machine learning              3  Dan Molodovan
# 1                           Big data              3   Anurag Nagar
# 2                   Machine learning              3    Anjum Chida
# 3                              Stats              3   Anurag Nagar
# 6  Design and Analysis of algorithms              3         Balaji
# 7                                CNN              3         arthur
# 8                                 AI              3           Haim
# 9                                NLP              3            Dan
#
#                Days  StartTime  EndTime    Location InstructionMode
# 0  Monday&Wednesday        9.0    10.15  ECSS 2.410               o
# 1  Tuesday&Thursday        9.0    10.15  ECSS 2.412               o
# 2  Tuesday&Thursday       10.3    11.45  ECSS 2.415               o
# 3  Monday&Wednesday       10.3    11.45  ECSS 2.410               r
# 6  Monday&Wednesday       16.3    17.45  ECSS 2.415               r
# 7            Friday       16.0    18.45  ECSS 2.412               r
# 8          Saturday       16.0    18.45  ECSS 2.410               r
# 9          Saturday       14.0    16.45  ECSS 2.415               r

# %%
#InstructionMethodIntent
result = None
instructionMode = "regular"
if(instructionMode.lower() == "online"):
  result = df[df["InstructionMode"]=="o"]
else:
  result = df[df["InstructionMode"]=="r"]
result
# Out:
#    Id    Term  TermYear Status  Section ClassLevel ClassSubLevel ClassNumber  \
# 3   4  Spring      2019      O  CS 4375         UG             S         126
# 4   5  Spring      2019      O  CS 5575          G            GP         12q
# 5   6  Spring      2019      O  CS 6575          G            GR         122
# 6   7    Fall      2019      C  CS 5375          G            GR         127
# 7   8  Summer      2019      C  CS 6375          G            GP         128
# 8   9  Summer      2019      O  CS 7375          P             P         129
# 9  10  Summer      2019      O  CS 1325         UG             F         120
#
#                           ClassTitle  CourseCredits    Instructor  \
# 3                              Stats              3  Anurag Nagar
# 4                                 DB              2         Davis
# 5                                SDN              1       Timothy
# 6  Design and Analysis of algorithms              3        Balaji
# 7                                CNN              3        arthur
# 8                                 AI              3          Haim
# 9                                NLP              3           Dan
#
#                Days  StartTime  EndTime    Location InstructionMode
# 3  Monday&Wednesday       10.3    11.45  ECSS 2.410               r
# 4  Monday&Wednesday       14.3    15.45  ECSS 2.410               r
# 5  Monday&Wednesday       20.3    21.45  ECSS 2.410               r
# 6  Monday&Wednesday       16.3    17.45  ECSS 2.415               r
# 7            Friday       16.0    18.45  ECSS 2.412               r
# 8          Saturday       16.0    18.45  ECSS 2.410               r
# 9          Saturday       14.0    16.45  ECSS 2.415               r

# %%
#CourseNameIntent
courseName = "machine learning"
termAndYear = ""
result = None
if(termAndYear==None or len(termAndYear)==0):
  result = df[df["ClassTitle"].str.lower().str.contains(courseName.lower())]
else:
  term = termAndYear.split(" ")[0]
  termYear = termAndYear.split(" ")[1]
  result = df[(df["ClassTitle"].str.lower().str.contains(courseName.lower())) &(df['Term'] == term) & (df['TermYear'] == int(termYear))]
result
# Out:
#    Id    Term  TermYear Status  Section ClassLevel ClassSubLevel ClassNumber  \
# 0   1  Summer      2019      O  CS 2375         UG            SO         123
# 2   3    Fall      2019      O  CS 1375         UG             F         125
#
#          ClassTitle  CourseCredits     Instructor              Days  \
# 0  Machine learning              3  Dan Molodovan  Monday&Wednesday
# 2  Machine learning              3    Anjum Chida  Tuesday&Thursday
#
#    StartTime  EndTime    Location InstructionMode
# 0        9.0    10.15  ECSS 2.410               o
# 2       10.3    11.45  ECSS 2.415               o

# %%
#ProfessorIntent
instructorName = "Anurag"
result = None
if(instructorName!=None or len(instructorName)!=0):
  result = df[df["Instructor"].str.lower().str.contains(instructorName.lower())]
result
# Out:
#    Id    Term  TermYear Status  Section ClassLevel ClassSubLevel ClassNumber  \
# 1   2  Spring      2019      C  CS 3375         UG             J         124
# 3   4  Spring      2019      O  CS 4375         UG             S         126
#
#   ClassTitle  CourseCredits    Instructor              Days  StartTime  \
# 1   Big data              3  Anurag Nagar  Tuesday&Thursday        9.0
# 3      Stats              3  Anurag Nagar  Monday&Wednesday       10.3
#
#    EndTime    Location InstructionMode
# 1    10.15  ECSS 2.412               o
# 3    11.45  ECSS 2.410               r

# %%
#CourseStatusIntent
courseName = "Machine Learning"
courseStatus = "open"
if(isStringAvailable(courseStatus)):
  if courseStatus == "open":
    courseStatus = "o"
  else:
    courseStatus = "c"
termAndYear = ""
if(isStringAvailable(termAndYear)):
  term = termAndYear.split(" ")[0]
  termYear = termAndYear.split(" ")[1]

result = None

if(isStringAvailable(courseStatus) and isStringAvailable(termAndYear) and isStringAvailable(courseName)):
  result = df[(df["ClassTitle"].str.lower().str.contains(courseName.lower()))
            &(df["Status"].str.lower().str.contains(courseStatus.lower()))
           &(df['Term'] == term) & (df['TermYear'] == int(termYear))]
elif(isStringAvailable(courseStatus) and isStringAvailable(termAndYear)):
  result = df[(df["Status"].str.lower().str.contains(courseStatus.lower()))
           &(df['Term'] == term) & (df['TermYear'] == int(termYear))]
elif(isStringAvailable(courseName) and isStringAvailable(termAndYear)):
  result = df[(df["ClassTitle"].str.lower().str.contains(courseName.lower()))
           &(df['Term'] == term) & (df['TermYear'] == int(termYear))]
elif(isStringAvailable(courseName) and isStringAvailable(courseStatus)):
  result = df[(df["ClassTitle"].str.lower().str.contains(courseName.lower()))
           &(df['Status'].str.lower() == courseStatus)]
elif(isStringAvailable(courseName)):
  result = df[df["ClassTitle"].str.lower().str.contains(courseName.lower())]
elif(isStringAvailable(courseName)):
  result = df[df["Status"].str.lower().str.contains(courseStatus.lower())]
else:
  result = df[(df['Term'] == term) & (df['TermYear'] == int(termYear))]
result
# Out:
#    Id    Term  TermYear Status  Section ClassLevel ClassSubLevel ClassNumber  \
# 0   1  Summer      2019      O  CS 2375         UG            SO         123
# 2   3    Fall      2019      O  CS 1375         UG             F         125
#
#          ClassTitle  CourseCredits     Instructor              Days  \
# 0  Machine learning              3  Dan Molodovan  Monday&Wednesday
# 2  Machine learning              3    Anjum Chida  Tuesday&Thursday
#
#    StartTime  EndTime    Location InstructionMode
# 0        9.0    10.15  ECSS 2.410               o
# 2       10.3    11.45  ECSS 2.415               o

# %%
# CourseStatus
courseLevel = "UG"
result = None
if( isStringAvailable(courseName)):
  result = df[df["ClassLevel"].str.lower().str.contains(courseLevel.lower())]
result
# Out:
#    Id    Term  TermYear Status  Section ClassLevel ClassSubLevel ClassNumber  \
# 0   1  Summer      2019      O  CS 2375         UG            SO         123
# 1   2  Spring      2019      C  CS 3375         UG             J         124
# 2   3    Fall      2019      O  CS 1375         UG             F         125
# 3   4  Spring      2019      O  CS 4375         UG             S         126
# 9  10  Summer      2019      O  CS 1325         UG             F         120
#
#          ClassTitle  CourseCredits     Instructor              Days  \
# 0  Machine learning              3  Dan Molodovan  Monday&Wednesday
# 1          Big data              3   Anurag Nagar  Tuesday&Thursday
# 2  Machine learning              3    Anjum Chida  Tuesday&Thursday
# 3             Stats              3   Anurag Nagar  Monday&Wednesday
# 9               NLP              3            Dan          Saturday
#
#    StartTime  EndTime    Location InstructionMode
# 0        9.0    10.15  ECSS 2.410               o
# 1        9.0    10.15  ECSS 2.412               o
# 2       10.3    11.45  ECSS 2.415               o
# 3       10.3    11.45  ECSS 2.410               r
# 9       14.0    16.45  ECSS 2.415               r
